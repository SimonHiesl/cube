# %%
s1 = "R2 U2 D' R' B R B U2 B2 R2 B2 U' B2 U' R2 B2 U2 R D' Fw Uw"
s2 = "D F2 R L' F R2 D F2 D2 B2 R U2 R' U2 F2 U2 L2 D B2 R2 Uw"

def scramble(scramble_string):
    scramble_list = scramble_string.split()
    for move in scramble_list:
        if move[0] == "U":
            if move == "U2":
                pass
            elif move == "U":
                pass
            else:
                pass
        elif move[0] == "L":
            if move == "L2":
                pass
            elif move == "L":
                pass
            else:
                pass
        elif move[0] == "F":
            if move == "F2":
                pass
            elif move == "F":
                pass
            else:
                pass
        elif move[0] == "R":
            if move == "R2":
                pass
            elif move == "R":
                pass
            else:
                pass
        elif move[0] == "B":
            if move == "B2":
                pass
            elif move == "B":
                pass
            else:
                pass
        elif move[0] == "D":
            if move == "D2":
                pass
            elif move == "D":
                pass
            else:
                pass
        else:
            break
    last_move = scramble_list[-1]
    pre_last_move = scramble_list[-2]
    if "w" in last_move:
        if "w" in pre_last_move:
            if last_move == "Uw":
                if pre_last_move[0] == "R":
                    if pre_last_move == "Rw":
                        pass # L B
                    elif pre_last_move == "Rw2":
                        pass # L2 U
                    else:
                        pass # L' F
                else:
                    if pre_last_move == "Fw":
                        pass # B R
                    elif pre_last_move == "Fw2":
                        pass # B2 U
                    else:
                        pass # B' L
            elif last_move == "Uw2":
                if pre_last_move[0] == "R":
                    if pre_last_move == "Rw":
                        pass # L B2
                    elif pre_last_move == "Rw2":
                        pass # L2 U2
                    else:
                        pass # L' F2
                else:
                    if pre_last_move == "Fw":
                        pass # B R2
                    elif pre_last_move == "Fw2":
                        pass # B2 U2
                    else:
                        pass # B' L2
            else:
                if pre_last_move[0] == "R":
                    if pre_last_move == "Rw":
                        pass # L B'
                    elif pre_last_move == "Rw2":
                        pass # L2 U'
                    else:
                        pass # L' F'
                else:
                    if pre_last_move == "Fw":
                        pass # B R'
                    elif pre_last_move == "Fw2":
                        pass # B2 U'
                    else:
                        pass # B' L'
        else:
            if last_move[0] == "U":
                if last_move == "Uw":
                    pass # D
                elif last_move == "Uw2":
                    pass # D2
                else:
                    pass # D'
            elif last_move[0] == "R":
                if last_move == "Rw":
                    pass # L
                elif last_move == "Rw2":
                    pass # L2
                else:
                    pass # L'
            else:
                if last_move == "Fw":
                    pass # B
                elif last_move == "Fw2":
                    pass # B2
                else:
                    pass # B'
    return scramble_list

file_path = "./scrambles/505440.txt"

with open(file_path, 'r') as file:
    for line in file:
        scramble(line)
